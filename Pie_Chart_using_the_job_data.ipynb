# %% [markdown]
# <a href="https://colab.research.google.com/github/charaf19/data_visualization/blob/main/Pie_Chart_using_the_job_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 #import required libraries 
 import matplotlib.pyplot as plt 
 # %matplotlib inline

# %%
#job data in percentile 
job_data = ['40','20','17','8','5','10']
#define label as different departments 
label = 'IT','Finance','Marketing','Admin','HR','Operations'
#explode the 1st slice wich is It 
explode =(0.5,0,0,0,0,0)
#draw the pie chart and set the parameters 
plt.pie(job_data,labels=label,explode=explode)
#show the plot
plt.show()
